-- %%
select sum(vehicles_involved) as Total_vehicles_involved,
 sum(casualties) as Total_casualties, 
  state from workspace.default.road_accidents_dataset
  group by state
  order by Total_vehicles_involved desc
